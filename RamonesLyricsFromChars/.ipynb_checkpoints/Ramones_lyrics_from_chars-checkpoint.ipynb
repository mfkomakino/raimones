# %%
'''Example script to generate text from Nietzsche's writings.
At least 20 epochs are required before the generated text
starts sounding coherent.
It is recommended to run this script on GPU, as recurrent
networks are quite computationally intensive.
If you try this script on new data, make sure your corpus
has at least ~100k characters. ~1M is better.
'''
from __future__ import print_function
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.callbacks import ModelCheckpoint
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys

# %%
path = get_file('all_lyrics_no-umlaut.txt', origin='http://research.komakino.ch/all_lyrics_no-umlaut.txt')
#path = get_file('nietzsche.txt', origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('corpus length:', len(text))
chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
# Out:
# Downloading data from http://research.komakino.ch/all_lyrics_no-umlaut.txt
# corpus length: 154121
# total chars: 56

# %%
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))
print('Vectorization...')
X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
# Out:
# nb sequences: 51361
# Vectorization...

# %%
for (i, sentence) in enumerate(sentences):
    for (t, char) in enumerate(sentence):
        X[i, t, char_indices[char]] = 1
        y[i, char_indices[next_chars[i]]] = 1

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# Build model...

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)


    
filepath="Word_weights-improvement-{epoch:02d}-{loss:.4f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min', period=1)
callbacks_list = [checkpoint]

# train the model, output generated text after each iteration
for iteration in range(1, 20):
    print()
    print('-' * 50)
    print('Iteration', iteration)
    history = model.fit(X, y,
              batch_size=128,
              epochs=1, 
              callbacks=callbacks_list)

    

    start_index = random.randint(0, len(text) - maxlen - 1)

    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print()
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x[0, t, char_indices[char]] = 1.

            preds = model.predict(x, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# --------------------------------------------------
# Iteration 1
# Epoch 1/1
# Epoch 00000: loss improved from inf to 0.85069, saving model to Word_weights-improvement-00-0.8507.hdf5
# 51361/51361 [==============================] - 23s - loss: 0.8507
#
# ----- diversity: 0.2
# ----- Generating with seed: " the seas of thought beyond the realm of"
#  the seas of thought beyond the realm of the darning areal clee
# the realing surfin' for me
# i'm a time bomb, baby
# i'm a time bomb, baby
# i'm a time bomb, baby
# i'm a time bomb, baby
# i'm a time bomb, baby
# i'm a time bomb, baby
# i'm a time bomb, baby
# i'm a time bomb, baby
# i'm a time bomb, baby
# i'm a time bomb, baby
# i'm a time bomb, baby
# i'm a time bomb, baby
# i'm a time bomb, baby
# i'm a time bomb, baby
# i'm a time bomb, baby
# i'
#
# ----- diversity: 0.5
# ----- Generating with seed: " the seas of thought beyond the realm of"
#  the seas of thought beyond the realm of the looks whane that it wants to walk whitl the forr
#
# when i saw your baby, i'm the bill i can't have spack up and ready to go
# oh no nown
#
# yat'm you though, i don't you easless of the reatin farin' some down
# it's gonna be the digh ranking to me
# don't wanna want you outta merry pain
# i'm gonna be the light to go
# baby i love you
# baby, baby
#
# don't want to come clast
#
# "bust and pestint and the
#
# ----- diversity: 1.0
# ----- Generating with seed: " the seas of thought beyond the realm of"
#  the seas of thought beyond the realm ofector traid that the ho safa
#
# will alled as her ba"sut
# and i tell ald happe to to the day never hard
# sheena be the street my friends
#
# i'm a placks oh yea
# life frieved something't complice.
#
# why wold go let "twer out to the ben these that i world
#
# a you don't got a looon of that froum to die you're frib mace
# thote's nay
#
# ssith and you tho wart kindey werl you drokimy shoop
#
# i got pass bady
#
# ----- diversity: 1.2
# ----- Generating with seed: " the seas of thought beyond the realm of"
#  the seas of thought beyond the realm of jouev.
#
# amouaking and they ho rock aron't with me
# men anigse my bears aliry ushride,
# yeah i know your flame
# hit bard bule too surf cricknevever'll eelows all a roughher
# do you took your looked me baby
#
# "baby, baby, i'm a little bere has ccrist
# the reamoshe sulf chome glle
# boters to tay too the the hase, a peapin
# i'm beciuse are know
# no one ereannnt gerrag will my s-u- as
# there's nothing
#
# --------------------------------------------------
# Iteration 2
# Epoch 1/1
# Epoch 00000: loss improved from 0.85069 to 0.83549, saving model to Word_weights-improvement-00-0.8355.hdf5
# 51361/51361 [==============================] - 24s - loss: 0.8355
#
# ----- diversity: 0.2
# ----- Generating with seed: "aight line
# they're going through a tigh"
# aight line
# they're going through a tight
# for my body know
# when i'm go from a nice don't you think i want it to me
#
# but i'm a surf to me
# don't you can get somebody to love
# you gotta live to me
# i don't wanna be tamed
# i am a tring would be strands it wish the stirty treatmer of you to me
# don't you can can crethin' to me
# don't you wanna see
# you know it's the only oned with me then i can't control myself in the stongth to endure
#
# ----- diversity: 0.5
# ----- Generating with seed: "aight line
# they're going through a tigh"
# aight line
# they're going through a tight
# so bust and the world, don't come cause i don't want
# i want you around like so from me
# i don't wanna be tamed
# i feel some mine
# i am a tetter on the hol
#
# they took my me my my my hey hatr my me in the was it will be trone
# we know it alive with me thind it on tve round a down to me
#
# don't wanna be to me
#
# i love her so bars a down the street chome it well
# i remember your gonna learn
# don
#
# ----- diversity: 1.0
# ----- Generating with seed: "aight line
# they're going through a tigh"
# aight line
# they're going through a tight
# you know it's thinking alone in stwpo to go i see
# it's twast not peode fone.
# hey! we come close
# you go, oh yea
# pal.in, oh yeah
# sho's the one, i've ainn't nead ang everybody tonight
# not anybody know were alain
#
# "to me ease
# this we know it the one
# oh baby, baby, my baby baby, caise me on how bablger in
# but why down the we wild be on this wanna wrond
# i'm working to go you outtiblot me
# you
#
# ----- diversity: 1.2
# ----- Generating with seed: "aight line
# they're going through a tigh"
# aight line
# they're going through a tights me so mon mone
# the we just a crest
# your bock ow the be'm laid they we coming of me
# merousks inucause me thin uch all serks of propher fortie
# always reback bodarer dermag before to riding
# and plyther's no mody
# you're go hocker funna down
# always makes losk
#
# sind it all welflial awa
# to wordy on u.
# 'cause in a becardy money ream my chmpsiles
# some your und
# there not i walking my pant me
# t
#
# --------------------------------------------------
# Iteration 3
# Epoch 1/1
# Epoch 00000: loss improved from 0.83549 to 0.82199, saving model to Word_weights-improvement-00-0.8220.hdf5
# 51361/51361 [==============================] - 23s - loss: 0.8220
#
# ----- diversity: 0.2
# ----- Generating with seed: "t,tonight
# wait-now
# wait-now
# hanging o"
# t,tonight
# wait-now
# wait-now
# hanging out of the mind
# i wanted every one on the roother something
#
# the street my heart a pramn, on show your boy
# with you go to she goee out of there
# i don't wanna be sad and they way
# i don't wanna be sad and the surts anywh you
# but it's gonna be to go
# i have go to gut
# don't to go
# oh yeah
# we went the know it was something
#
# i don't wanna be sad and they way
# i don't wanna be sad and they way
# w
#
# ----- diversity: 0.5
# ----- Generating with seed: "t,tonight
# wait-now
# wait-now
# hanging o"
# t,tonight
# wait-now
# wait-now
# hanging out of strees oh yeah
# perhaps choperapy
# any i got a lot to sty out he goel
#
# and i don't wanna wank you around
#
# we want you to goend
# i have the tells
#
# with you i want you and into the say
# a funna be all cream
# i'm beggin' for me on a fally merry show he have to gub
# the kkkn what what they do what day
# we want the girlly way
# you gotta me with you think wind
# wish the onlerd down the tellsher
#
# ----- diversity: 1.0
# ----- Generating with seed: "t,tonight
# wait-now
# wait-now
# hanging o"
# t,tonight
# wait-now
# wait-now
# hanging out the surtth the cret
# so i saw you better the surtrice
# i'm gonna faved to telr
# i know
# now that's gonna done
# work"
#
# we you can down to go
# s-e what thry rememone , now i feel steran me, he just can't stall
# med one every ranker "the grom
# she say give airsel friegh, i love her ligh
# for and simes with chas y-
# you got all the lond on the coother and playing and your hipie
# i am not want down
#
# ----- diversity: 1.2
# ----- Generating with seed: "t,tonight
# wait-now
# wait-now
# hanging o"
# t,tonight
# wait-now
# wait-now
# hanging on the roothe, rock-of
# b
# we whink it's goin'
#
# and surf to the
# cipd slees up and wantat fitide what
# she cards dog
# stard, yeah, cal'se alone
#
# new with a glowing.
# opers kinderer you go in my sold's and ruke air chubo you
#
# "i still doffe's aid anciuges the fight it wild
#
# but when i evep to outf rolls that
# my fourger of cought ment
# pows
# you took i see happy girl you go "t'y good the gough you
#
# --------------------------------------------------
# Iteration 4
# Epoch 1/1
# Epoch 00000: loss improved from 0.82199 to 0.81209, saving model to Word_weights-improvement-00-0.8121.hdf5
# 51361/51361 [==============================] - 24s - loss: 0.8121
#
# ----- diversity: 0.2
# ----- Generating with seed: "l me how to love my baby
# she belongs t"
# l me how to love my baby
# she belongs to me
# don't you can hen the begging to go
# oh no
# no no no worrant the way
# it's not a could to go-ooh-oh-oh
#
# baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, b
#
# ----- diversity: 0.5
# ----- Generating with seed: "l me how to love my baby
# she belongs t"
# l me how to love my baby
# she belongs to me, a can't you think you look litt fine
#
# go life's a gas, life's a gas, ally ain't heart and the forr
#
# sting in the street for say
# hand of the girl
#
# he's a roy
# and in the furtaring
# i can't seemat to the game
# makin't last frist
# thery hanging down to never go the beal
# don't wanna be the gone
# when i'm playen, i had that you do in a celled and your how
# baby, baby, baby, baby, you think m
#
# ----- diversity: 1.0
# ----- Generating with seed: "l me how to love my baby
# she belongs t"
# l me how to love my baby
# she belongs to know
#
# when i see not the jock to the see
# a bring, whe streenty
# pp
# net someheal
#
# what's that string on agound
#
# want make like by so bucks
# i remerble can h und blone
# deatllammet the naghtk
#
# you say to you wanna live. o.
#
# weht's no out that kin
#
# ooh, head
# laoning, in dia boy where's got to end
# i don't wanna rnget for the holl
#
# she lain crusaring me
# a nim, on she lies around
#
# 'cause i fe
#
# ----- diversity: 1.2
# ----- Generating with seed: "l me how to love my baby
# she belongs t"
# l me how to love my baby
# she belongs than you drop
# bop-you care', bad bake you beties
#
# and you look litt my'e the bore
#
# "i heard sing in the game
# like her cal her.
# i fell i wall, well my fnew i kin
#
# just poce. likedy
# just are lottle magnilg, i'm thinking quecine
# i'm gonna bel
# is it saying me, tonitht tht
# and the never drive
#
# come back, rocdion my mondaming
# all the moveryont
# to rebophers me"
#
# hey, cablin
#
# dever"bumiloctys
#
# --------------------------------------------------
# Iteration 5
# Epoch 1/1
# Epoch 00000: loss improved from 0.81209 to 0.79780, saving model to Word_weights-improvement-00-0.7978.hdf5
# 51361/51361 [==============================] - 24s - loss: 0.7978
#
# ----- diversity: 0.2
# ----- Generating with seed: "always stiff, it never fails.
# now it on"
# always stiff, it never fails.
# now it on the sheppone out of little her man
# out of love, the mashed when she saway back
# any out you wanna be sedated
# you look me what to do
# don't you can ever looking on the shepper
# i can't the wat something to me
# baby a lot a fay
# it's not my place chee
# hang of a little on the surtift feelt heart,
# i know i want you around
# i am a to knot out a nice her do
# don't wanna be seart i know
# the only th
#
# ----- diversity: 0.5
# ----- Generating with seed: "always stiff, it never fails.
# now it on"
# always stiff, it never fails.
# now it on the sheet fighting in a falisace pace
# nothin' to do no the hat and was school of theme
#
# "heysang on a fack the parn the firdents to go
# and in my mind
# the round of love, tell mely looks whople cret
# if i see in go more from me
#  aby, babybaby
# come on baby shoot
# and i don't know what to be the see
# she said, now i was some has day.
#
# i can't seem to make you mine
# i am a tu know what to twe
#
# ----- diversity: 1.0
# ----- Generating with seed: "always stiff, it never fails.
# now it on"
# always stiff, it never fails.
# now it on touble ese sho asteanin
# and pleally like for it looks learn
# yust as bun oruid, wh.
# berted out of the younger how is the dangentproface
# and so no sheng that that will o
#
# swell wish your real pland, you're gonna leave
# and the world for know
#
# ver this was sheetaco
# 'cause lotel, roll ajost fine
# can hears a pinhonce
# i know i hulse
#
# "hey! greatliss, rash"
#
# i cause on know girl everybody lon
#
# ----- diversity: 1.2
# ----- Generating with seed: "always stiff, it never fails.
# now it on"
# always stiff, it never fails.
# now it on smisting on
# i saw head and day
# nothain"i ou need look pint why sound
#
# pame shiptle foom by so
# exe bit a lot oor
#
# go life and down to l.ak
# clast kears kiss and kimper
# you're with me one
# come sane
# "ighutt"
#
# don't want to goct up, non
# let chat you neeh out of theres sone of fight
#
# baby make me loboy loob so buz
#
#
# buby on my swent you wants with me
# and you'll prit.
#
# figh out of me,
# is
#
# --------------------------------------------------
# Iteration 6
# Epoch 1/1
# Epoch 00000: loss improved from 0.79780 to 0.79328, saving model to Word_weights-improvement-00-0.7933.hdf5
# 51361/51361 [==============================] - 23s - loss: 0.7933
#
# ----- diversity: 0.2
# ----- Generating with seed: "ndian giver, indian giver
# you took your"
# ndian giver, indian giver
# you took your love me so man
# it's net her whaned to love
# don't learn to leave
# it's not me on a face
# the say her said, hat
# she masing in the day
# with me to me
# come on baby
# baby, baby, baby, oh i love her so oh oh oh oh oh oh oh
#
# ma ma ma man in me so me on a girl
# the dangers of love, tame, llans to love
# don't leave me shan
# she was she said, that's no more
# down a little of the night of the night
# w
#
# ----- diversity: 0.5
# ----- Generating with seed: "ndian giver, indian giver
# you took your"
# ndian giver, indian giver
# you took your show to she gair to be all my bean
# come on baby baby
# i don't lear
# you gotta live, to lease you are after day
# i can't tell me, tell mellap like a boy to tougher happy
# and warly to live. that i down
# i don't wanna be a pleays tell becaution
# it's gonna be a good the world
# i can't control myself become shape
# he say her was crazy
# i'm making in the day
# no more is head all right
# i don't wanna
#
# ----- diversity: 1.0
# ----- Generating with seed: "ndian giver, indian giver
# you took your"
# ndian giver, indian giver
# you took your skil it gonna care
#
# 'cause in down surfle in she says
#
# 't i said you two
# you wrongsey keeparcen give me oord so
# the bleys for me, crazy
# it's  five into sade of mind
# with ming
# to know
# it's not no more, i miss you vies your babsk
#
# with got to me, and i tell dead and threing abou down
# it's the part
# she said, beracr and ugdirine
# i don't care, sell it see her.
# i'm a gue, to ruch alone
# sh
#
# ----- diversity: 1.2
# ----- Generating with seed: "ndian giver, indian giver
# you took your"
# ndian giver, indian giver
# you took your lide am in to get it the mad
# let's demnistol
#
# "i
# it's no more you lookel, love somebody put it just go
# no one the dance baby to me
# and
# iide wart all my love
#
# .o. rain
# well we do any ot for kinding to see
# you wither thinkain
#
# your sation my mows were hard
# the mashed back weag canse
# i won'r dry
# funn' anntht go to world i warkd
# new you long inlieve in a wan
# still crett"
#
# buran heally f
#
# --------------------------------------------------
# Iteration 7
# Epoch 1/1
# Epoch 00000: loss improved from 0.79328 to 0.77865, saving model to Word_weights-improvement-00-0.7786.hdf5
# 51361/51361 [==============================] - 24s - loss: 0.7786
#
# ----- diversity: 0.2
# ----- Generating with seed: " the street
# down in the playground the "
#  the street
# down in the playground the street free
#
# anver gonna treat to me
# i want to say her go
# and i treane to leave you
# i love you i remember you
# baby i love you and i took and it the tody
# there's a headbanging how
# still my heart of durty
# there's a headbanging how
# we can give to me
# and you to do you to do
# i want you around
# it's getting to see so say
# a little the manking in the death of them
# it's the end
# to me my sheea
#
# ----- diversity: 0.5
# ----- Generating with seed: " the street
# down in the playground the "
#  the street
# down in the playground the break it cold no more. litels are foor home
# i can't remember now
#
# i clet last now the really do then youn
#
# "i am a telling, all of dring, indan it batt for my heart a bratul
# it's getter you trook
# bop all me
# any though, baby
# oh baby, i had to dust the lone
# well i treat to do you too baby tour like the gonna stranger
# i can't ever be the end
# the presed sation fill
#
# and i can't say
# i lootin
#
# ----- diversity: 1.0
# ----- Generating with seed: " the street
# down in the playground the "
#  the street
# down in the playground the catch up and roul
# i saw her  too burnag say
# to mean chacined mers prack
# s"
#
# love the breaghinj
# he don't then then you goie
# and i treat try twoom
# thereze of just mane, i hon
# my litt prebace cree
#
# say in the reafing is always i'r heast time
#
# "and i had to my old i ho man
# i am a tu su for no more. i just wanna be whet inse and make
#
# guy tomorne day out of the mornedce
# she's a girty on the s
#
# ----- diversity: 1.2
# ----- Generating with seed: " the street
# down in the playground the "
#  the street
# down in the playground the madp
#
# a couties screegt this crummy soer rufusome
# hell come on - ammymoppelow cree
# i am akide
# you're to enjor wabstec ream
#
# glade gyerdbis when youity
# oh, baby
# come on do
# "just as butaliod me rockna
# baboh-us
# clos you pay bable's chasing up aftice dorr
#
# i c.n't hell,  little pryat fight for no could cold was round
#
# "dongerapped auning"
#
# i'm alright, it's get insto wathing put any
# moper-ja
#
# --------------------------------------------------
# Iteration 8
# Epoch 1/1
# Epoch 00000: loss improved from 0.77865 to 0.76905, saving model to Word_weights-improvement-00-0.7690.hdf5
# 51361/51361 [==============================] - 23s - loss: 0.7690
#
# ----- diversity: 0.2
# ----- Generating with seed: "- ay, hay
#
# "i won't let it happen"
#
# got "
# - ay, hay
#
# "i won't let it happen"
#
# got a loaggs the street for my pronat baby
# come on baby make me shroon
# slare, i don't want to live this life me
# and i treat to die
#
# i am a temose my life
# i can't seem to make you mine
# i can't stabt it and it's not me
# everybody and the forry the street hatioh out
# foatt my brain my shock treatment for the storment gowney i took i want you around
#
# i don't want to be my friend
# the dangers, its t
#
# ----- diversity: 0.5
# ----- Generating with seed: "- ay, hay
#
# "i won't let it happen"
#
# got "
# - ay, hay
#
# "i won't let it happen"
#
# got to always are never had ind
# i don't want to be mow out i headbanging
#
# this around, drives peecop
#
# i want to know, hair frob fun
# here here and something to see she well
# and i don't know where to go-oh-ooo
# come on and the dolkento wire
# i said bost from a crycared in the start drivilg
#
# sterming me whis better your hog
# when i saw you do you want it
# the round with me your body don't come sie
#
# ----- diversity: 1.0
# ----- Generating with seed: "- ay, hay
#
# "i won't let it happen"
#
# got "
# - ay, hay
#
# "i won't let it happen"
#
# got a still now i know go to go houl
# the one she say they have the usee
#
# we well i'm beally world
# don't want go tady
# las, like a be'ttt mine, oh no no
# you don't know what to do
# you wanna street and sleep
#
# palking may have stay
# and where she stold something to reacher face
# in a tell no, i ease and i walk
# right you skiesus oh yeah
#
# she went looked you
#
# i have the streatees of undy make a poo
#
# ----- diversity: 1.2
# ----- Generating with seed: "- ay, hay
#
# "i won't let it happen"
#
# got "
# - ay, hay
#
# "i won't let it happen"
#
# got a loare's wrong, head lost forgen a spider, yeah, i dona now your love
#
# i want to feeld and it fell thisk rine
#
# up they're come as depop
#
# wrong igut in the carcted to play
# apeay rillown, all wro my shee in micpybor.
# eze i'rd kidster lowne.
# i wanted worldn't leake to live
#
# "where's a gas, the swais, i know you stiper my mind
#
# ta
# hanging a
# lawale for pulis worr
# king when it best nom
# a see'
#
# --------------------------------------------------
# Iteration 9
# Epoch 1/1
# Epoch 00000: loss improved from 0.76905 to 0.76618, saving model to Word_weights-improvement-00-0.7662.hdf5
# 51361/51361 [==============================] - 24s - loss: 0.7662
#
# ----- diversity: 0.2
# ----- Generating with seed: "losin' kind
#
# endless vacation
# endless "
# losin' kind
#
# endless vacation
# endless very happ no more. i just love you
# baby i love you surfing it with you this live
#
# well i'm against it's alrightte, herk she says
# and that's where i had word
# you wanna be a go
# don't wanna be tamk and in the tell be
# they want to start to see what it's alright
# i am a tu tu tu tu tu tough tough guy
# hand that happen
#
# when i saw you are the stree her
# baby, baby, ah, baby
# i know it me anything
#
# ----- diversity: 0.5
# ----- Generating with seed: "losin' kind
#
# endless vacation
# endless "
# losin' kind
#
# endless vacation
# endless ery all with the gamman mentanger, no no
# i treande to say
#
# i wanna be to go
# bus so with you sone...
#
# "
#
# i can't say and in love, to see what they we where a prethy stold
#
# but no make me mansed now i be trean
# somebody has a poison heart a girl
# i lost mentaling to me, all around
#
# "i wanna have somebody put something to be rock n'w wait cabbies
# i don't wanna be a go
# baby
# baby i love you and
#
# ----- diversity: 1.0
# ----- Generating with seed: "losin' kind
#
# endless vacation
# endless "
# losin' kind
#
# endless vacation
# endless 's streemty an's for king out it make me 'seen a little bit glaeag it's alright, it's alright, and psand me, have to me
# don't wanna dess around like
# and thing to probap withured mental..
# anxiety, frine, e-gongamy for the way
# i wanna have so take the dightin' surfice
# morrom ass-
#
# ----- diversity: 1.2
# ----- Generating with seed: "losin' kind
#
# endless vacation
# endless "
# losin' kind
#
# endless vacation
# endless very eacl
# you have the mike of dain
# with you thmoth why make you"
#
# ono lies as farl
# i'm just bakiss an from high, by, oh-oo--oop-oh-oh
#
# bop do
# kkdon't goid you, hanging to becaus lighting took annga, a somes of pight
# just like this your lide are und that it's wore, gonna have somebye tonight rings we-eating ...
#
# "carethjveririon min"
#
#
# yeahin' vemasarous treatment
# ifamighted the bagg in the
#
# --------------------------------------------------
# Iteration 10
# Epoch 1/1
# Epoch 00000: loss improved from 0.76618 to 0.75770, saving model to Word_weights-improvement-00-0.7577.hdf5
# 51361/51361 [==============================] - 24s - loss: 0.7577
#
# ----- diversity: 0.2
# ----- Generating with seed: "s were so achey
#
# you didn't mean anythi"
# s were so achey
#
# you didn't mean anything to be the reatic, we see the did
# the dangers, i saw you are she say find a little bit the new
# the didpely chops of love, tomorrow is the were the rains a little bit the stormer on the rains
# i don't wanna wain
# i don't wanna wank you think my life
#
# i am a to want you no more. i just me
# no no no no no wi widy
#
# there's no one the reating start fight no more.
# to last me to day
#
# i don't wa
#
# ----- diversity: 0.5
# ----- Generating with seed: "s were so achey
#
# you didn't mean anythi"
# s were so achey
#
# you didn't mean anything to see whis some
# i am in the masime mars, yeah, you're gonna leave
# let's go
# it feel the onlyt
# i don't care
# i don't look and it all her
# chop suey
# chop suey
# chop suey
# chop suey
#
# no no no no no no workd
# they not she will the dangers
# come on and safari)
# i can't remember boy, rock, rock, rock'n'roll really do so bur
# but no more the unheart and punkser and safari)
# i was feeling tho g
#
# ----- diversity: 1.0
# ----- Generating with seed: "s were so achey
#
# you didn't mean anythi"
# s were so achey
#
# you didn't mean anything that for the storme
# badr, baba-bamy, keep, 'he i said
#
# ah, timebody hear
# say haw a hope
# they never pain the goney, i'm against that ate who the breat to death
# they're sasion
# you gonna goen the lies sere my heart
# i can't control myself it prolly in dong
# door of dament, you're gonna see insk torock to and
# now i was some-bah, i don't wanna rnigh rome, what it's witht
# it never can't essee
#
# ----- diversity: 1.2
# ----- Generating with seed: "s were so achey
#
# you didn't mean anythi"
# s were so achey
#
# you didn't mean anything to worry about you're bock and i ckntroation
# creebin') ty"
# hey, rome on in hivistarn and i wast it like somebot.
# see, she never do
# this changes
# i'm roll is suchead for a was around
# that's there i hope i twop tot
# i thopo'r rank raid i'm right
#
# kindend of your did, lood cretsapy
#
# and thereing winhead we love
# don't tale to come to
# i was bore i gues you toke in a rought
# aing the bightin' h
#
# --------------------------------------------------
# Iteration 11
# Epoch 1/1
# Epoch 00000: loss improved from 0.75770 to 0.74981, saving model to Word_weights-improvement-00-0.7498.hdf5
# 51361/51361 [==============================] - 24s - loss: 0.7498
#
# ----- diversity: 0.2
# ----- Generating with seed: "ion
# 'cause you're so lazy
#
# you sound l"
# ion
# 'cause you're so lazy
#
# you sound like a sun and i treat to die
# hang on a lit lik at the monger so me to ee
# hey! radily girl
# the way i walk
# ring with me
# i don't like fight rocker
# sheena is a punk racker
# a wanna have they good the way i was and the one
# i saw you and i tell you i want you anything
# i don't wanna grow up
# so but what you want it the way
# i don't like to go baby and i dostare
# a beatten to learned you tried and
#
# ----- diversity: 0.5
# ----- Generating with seed: "ion
# 'cause you're so lazy
#
# you sound l"
# ion
# 'cause you're so lazy
#
# you sound like a sun the mash you sone
# now i'm gonna craid and the was scheepa it world to goo
# worlartand it was and they're going the one
# a beatt face it's not for me to know
#
# i want you an end you tried and i treat to me
#
# don't talk to me
# and i don't know why well you see
# and i can't wait to be mine
# i don't have go to do
# he's go of too the cathing
# i saw yo
# we a treid anybody
#
# she was erried c
#
# ----- diversity: 1.0
# ----- Generating with seed: "ion
# 'cause you're so lazy
#
# you sound l"
# ion
# 'cause you're so lazy
#
# you sound little show
# a hold you walk away
# but i don't know what to say
# i can't goin' out
# feed no one the one
# he'll dranking why saw you
# and yoursand it good everyon
# i don't like me that you good any-ne, she could saver affasiin't of just as buster to eunned you're hate
# the dangers of lat, a poound someble
# i am not afriek for and drank
# ain't think it baby, really do
#
# so buride "ill, be, a best it
#
# ----- diversity: 1.2
# ----- Generating with seed: "ion
# 'cause you're so lazy
#
# you sound l"
# ion
# 'cause you're so lazy
#
# you sound laye my cretin wist, did wish deady hey hey
# believe a reaph and look hour hip,
# and wine"d
#
# "betiation"
#
# hey, yeah i got for
# the with you sheet been't know gotoway for you unet's to learn
# )athe, yeah
#
# i did when you swiffin' safari) went see of sterman
# i got togorn"
#
# i got say her.
# anwing your time
#
# let it oles up pleannt
#
# little make her and me
# i danced stay
# aloer hairingers suff theiss
#
# --------------------------------------------------
# Iteration 12
# Epoch 1/1
# Epoch 00000: loss improved from 0.74981 to 0.74290, saving model to Word_weights-improvement-00-0.7429.hdf5
# 51361/51361 [==============================] - 23s - loss: 0.7429
#
# ----- diversity: 0.2
# ----- Generating with seed: "our lid
# they say you're just an awkward"
# our lid
# they say you're just an awkward
# steepin' ramans are aff the didulit
# she was enow i was some
# i don't wanna go to wor to go
# oh i look it hear to start
# don't go, don't go
# don't go, don't go baby do
# i don't wanna go to the say they say
# hey, hey, hey
# we can girl come along on the stir fatt for the end
# i can't control myself on the stir beat to fill that
# she never get the did
# new is back a real the bus
# i was a read the b
#
# ----- diversity: 0.5
# ----- Generating with seed: "our lid
# they say you're just an awkward"
# our lid
# they say you're just an awkward
# do you i can't go to workd
# her when i'm gonna be a stood her sought a truck
# hey dan't got no more
#
# "babys i head get a fay
# it surfin around alone the say
# any out of something i was from me to know
# it's not me any one oh yeah
# we can out the dangers of love
# sweenad to the see girl come a me to angle no more
# a be to but she went down
# i was frol this way
#
# now i wanna be alright
# and i trea
#
# ----- diversity: 1.0
# ----- Generating with seed: "our lid
# they say you're just an awkward"
# our lid
# they say you're just an awkward
# yeah rang
# i'm beggt
# there's no one oh yeah
#
# i'm clazon fin
#
# your wake of a girl
# where i'm gonnt that you around
#
# "life fine"t and they're going
# i feel start kily come took you, ones they're to me
# in a fime, he now why
# he's got the eaticin'
# psobappine"
#
# i can't seem to fight tonight that pace
# you make me wanna set her screeflize
#
# i am a to dow
# you knvere
# when i shook all down.
# a hop
#
# ----- diversity: 1.2
# ----- Generating with seed: "our lid
# they say you're just an awkward"
# our lid
# they say you're just an awkward
# well 'mis funna crazy, there's anntring day
# he's gonna beanalifch, you tull stare hap
#
# 'cause everybody's littentrout my breat,
# they ain't but i psanith with the bind
# roc's os for you our
# sopeds
# i'm againsp it just about to me
# ever know thy no-roodver facer
# girl, i'm looking love
# don't teid the knave to the barsfin
#
# don't bebigst save an old never of the drink
# i walking out of zeery pri
#
# --------------------------------------------------
# Iteration 13
# Epoch 1/1
# Epoch 00000: loss improved from 0.74290 to 0.73999, saving model to Word_weights-improvement-00-0.7400.hdf5
# 51361/51361 [==============================] - 24s - loss: 0.7400
#
# ----- diversity: 0.2
# ----- Generating with seed: "rn
# you gotta learn to listen, before yo"
# rn
# you gotta learn to listen, before you like my life
#
# they wanna be the gast
# what the say heart angstmentalibight on the cool
#
# well, i had i to wordy that swe the goe
# well i treat the firsee
#
# "better bease aglanged the street for my friends
# well let's dance, well let's dame
# what was the say they go say herrang
# the street have the street little bit oot
# i can't can girl hop out a lottle my mind my friends you shop
# baby i don't
#
# ----- diversity: 0.5
# ----- Generating with seed: "rn
# you gotta learn to listen, before yo"
# rn
# you gotta learn to listen, before you like my life's a goo, never get the street fing to listen
#
# and i don't like me wind
# i don't care
# come on baby baby baby
# baby, baby, oh love her so for my baby
#
# don't ste my has acpoes
# leate my little of the rain
# i can't take the night
# with the night now
#
# i herd the nemple her say herr
# heads of love, lace for the woother the show
# she's a little bit oot out of the higher that they was t
#
# ----- diversity: 1.0
# ----- Generating with seed: "rn
# you gotta learn to listen, before yo"
# rn
# you gotta learn to listen, before you line , your chain
# hanging you glone ong tuttated, the gamma surfing alone everything
# i tell i'm gonnat, now it's alright
# it's gen to wire, i donfa give and me, your stwas
# kiss apering wish, hey neh look
# and i'm againsy do
#
# i'm plasace away from memany
# i am a tu away it's alright
#
# anwave heart face it can't have to go
# oh i love the cirdes
#
# ain't your end your elwalor
#
# mome for the shape
#
# ----- diversity: 1.2
# ----- Generating with seed: "rn
# you gotta learn to listen, before yo"
# rn
# you gotta learn to listen, before your lide end astsomayble spidgling, tonightton's ngwase, .o.
#
# "metyback, come bock aways go
# and the gushers in the was almostl
# drony, drank fride, lood , chanke my
# go for the change
# sheena is a punk rock
# no didr wilk turmes
# you're wise sitinoutien
#
# well, the gsmith the rain
# human any, kisser dies cream
# he's a gus, the mart, theary, i can't tasted out
# o.n. in there the glatise it name
# hea
#
# --------------------------------------------------
# Iteration 14
# Epoch 1/1
# Epoch 00000: loss improved from 0.73999 to 0.72915, saving model to Word_weights-improvement-00-0.7292.hdf5
# 51361/51361 [==============================] - 24s - loss: 0.7292
#
# ----- diversity: 0.2
# ----- Generating with seed: ", for people acting this way
# tell me, t"
# , for people acting this way
# tell me, ter my heart a good away
# if you're a romembelse the street little drise
#
# now i don't know why
# come on and save to get in my life
# now i don't know why i don't love to be this way
# i don't wanna rneed no more
# oh, oh baby, don't love me my mover my moup
# baby i love you
# now you do you do
# i don't wanna dance?
#
# what you wanna dan't say anything to did you surfin' safari)
# yeah, terming mental.s
#
# ----- diversity: 0.5
# ----- Generating with seed: ", for people acting this way
# tell me, t"
# , for people acting this way
# tell me, to me, ah, real like a doan to me
# don't be sad are afchered my bratiol
# dron of time
# we need cancej
# you wanna real for its to cop
# some mine my shoop to put the hog
# but things youngers the girl my friends
# i don't wanna rneed no more
# oh, baby, baby, baby, baby, baby, baby, ah, yo do
# he life with to rock
# the room my burients will be trune, oh
# a honea fun, baby, baby, baby, baby, baby, ahhed
#
# ----- diversity: 1.0
# ----- Generating with seed: ", for people acting this way
# tell me, t"
# , for people acting this way
# tell me, tell me what do
# so i can't be little before you baby,
# killing somebody to love
# don't you card to our round
# if you wat somehowed life someone
# a bert me of congth to the eecovery frime
# baby, baby, baby, oh yeah's go
# so to be
# i don't out of tho mechersening
#
# timebop, call, prock, baby,  can we leake to be fast
# 'cause in murack misser going to be
#
# don't wanna read to pleake my list chin'
# f
#
# ----- diversity: 1.2
# ----- Generating with seed: ", for people acting this way
# tell me, t"
# , for people acting this way
# tell me, thingling meptell, my heart away
# gut the realing to lives to goin' tuch girl ho.
# i don't lone to the ta"t the kk would buck
#
# "there's veean't comma nich, ponges what
# bbott good the hog
# why wind ma me is surcruched eatic
# piname m,
# mu-  rag now
# it's not that lo mer
# of the streati from me you're heee
# eyery faraficilot
# tilling out of 'y tho meon
#
# "my friments longhurded band they high.
# i gut
#
# --------------------------------------------------
# Iteration 15
# Epoch 1/1
# Epoch 00000: loss improved from 0.72915 to 0.72465, saving model to Word_weights-improvement-00-0.7246.hdf5
# 51361/51361 [==============================] - 24s - loss: 0.7246
#
# ----- diversity: 0.2
# ----- Generating with seed: "my mom and dad
# " won't be sad about it
# my mom and dad
# i won't be sad about it
# i'm a nimouse to leavely to get it all of the bus
# i feel look me what you see to do
# wron awauskind, where i still my heart she talk
#
# the dreams the shope openant
# and the way it'r like to leave
# she tresade sutiand
# there's no hold my baby
# i'm a time bomb, baby baby
# i want you around
#
# you fell in ran in the day
# there's the easterolf
# the street my heart she says strath a little bit of a sa
#
# ----- diversity: 0.5
# ----- Generating with seed: "my mom and dad
# " won't be sad about it
# my mom and dad
# i won't be sad about it
# spide on a realh the street for a poorop
# scattergus, here in a rolly drank
# the street here we comeron be the elver
# she drisasiment, gonna
# well i'm affected, i don't know i walk awout the ty
# there's nothing to me
# the streents the higherly mind
# i can't seem to make you
# baby, baby, baby, oh i still now it's no lain
# it's not my place
# you trying, i'm alway
# but you're gonna have the how i do
#
# ----- diversity: 1.0
# ----- Generating with seed: "my mom and dad
# " won't be sad about it
# my mom and dad
# i won't be sad about it
# slaid around
#
# i rmadv, the sun too tough to see shink
# oze i wondr freenn gonna love out of us
# i my cretts life is like a day
#
# when i saw a dockerday boney
# you make me say bany
# go, the sungeret find i used to know
# just haguthty trucas
# there's no she was something in the cenntryttay
# it ma"station
# and all my heart she saw a hold oorcewoned facho
# come on never had ind a strange
# you tried s
#
# ----- diversity: 1.2
# ----- Generating with seed: "my mom and dad
# " won't be sad about it
# my mom and dad
# i won't be sad about it
# come on gonna have somethin'
# she if your real kiss from me, this astronight, to from you, come on tomornet chirone
# she treat out, haid dainfappin in the troumd
# girl dorrows"
#
# when your proys they iffus
# - ay
# 'cause .very lookings to what.
# walun, time"
#
# fin't you get such a pictow it a do'
# no one thur, have the sterm, thy dides
#
# you thinkingness ze my
# we wha whare  fuce
#
# uarienind, froug
#
# --------------------------------------------------
# Iteration 16
# Epoch 1/1
# Epoch 00000: loss improved from 0.72465 to 0.71836, saving model to Word_weights-improvement-00-0.7184.hdf5
# 51361/51361 [==============================] - 24s - loss: 0.7184
#
# ----- diversity: 0.2
# ----- Generating with seed: "y, set on you
# the things she said, well,"
# y, set on you
# the things she said, well, come back
# i want to go
# one our be true
# i wanna be alresty now
#
# and i don't want to live this life mencane on a morn
#
# and i don't want to live this lift me told me tonight
#
# "i can't get that's no way to see what
# i wanna be alresty kicks somebody to love
# somebody pull me today
# i'm gonna be the didpers and fighting me to me
#
# dan't you know your biger things to me
# i'm gonna be the death
# i
#
# ----- diversity: 0.5
# ----- Generating with seed: "y, set on you
# the things she said, well,"
# y, set on you
# the things she said, well, shan and in the day
# she says a little heran is straing
# to the pain bean, mace crues
# there's some of the poessed now
# i can't hanger
# go to well i can a want it one oh yeah
#
# i can't teld it and into the surfin' surrock to the chasce
# hey now i walk when i drows of the powey
# she was everything to me
# i don't know could still for you out
# we want the way
# i'm gonna be your body, baby
# i don't w
#
# ----- diversity: 1.0
# ----- Generating with seed: "y, set on you
# the things she said, well,"
# y, set on you
# the things she said, well, me pain
# iffon, baby, to les, mefoolp you .
# oh baby, don't go, baby they i'm roin
# i am let my heart i know
#
# i lost my mind ofccome
# in a ni-e, yeah, crack
#
# ind was hoppinp"
#
# i want you around
#
#
# you thway
#
# i don't be wind to me
# you wanna warcriest canjeh
# she headcasitiess your mide hind every
# peased the game
# we cante why world them chace
# she wanna be an on always the streind, high a troe
#
# ----- diversity: 1.2
# ----- Generating with seed: "y, set on you
# the things she said, well,"
# y, set on you
# the things she said, well, chain't friend
# to celd creshy
#
#
# she's lainna
# just ones east of your bearing
# i know pleass,
# don't wanna friendy to
# some bake
#
# come back, make for you oh oh no no
# on't no one oney (surfin' love the fight
#
# tallin' headbatting, baby, deahted mafful the very gonna
# well me, hell, things the waycare
# tolds the truchin just could frieg
# i goin' out merons i just know i tho outta top
#
# i can
#
# --------------------------------------------------
# Iteration 17
# Epoch 1/1
# Epoch 00000: loss improved from 0.71836 to 0.71543, saving model to Word_weights-improvement-00-0.7154.hdf5
# 51361/51361 [==============================] - 33s - loss: 0.7154
#
# ----- diversity: 0.2
# ----- Generating with seed: " the air is still,
# all of a sudden i fe"
#  the air is still,
# all of a sudden i feel like so but i don't want to do you're and it look at your face
# when your body is a punk rocker
# sheena is a punk rocker
# sheena is a punk rocker
# sheena is a punk rocker
# sheena is a punk rocker
# sheena is a punk rocker
# sheena is a punk rocker
# sheena is a punk rocker
# sheena is a punk rocker
# sheena is a punk rocker
# sheena is a punk rocker
# sheena is a punk rocker
# sheena is a punk rocker
#
#
# ----- diversity: 0.5
# ----- Generating with seed: " the air is still,
# all of a sudden i fe"
#  the air is still,
# all of a sudden i feel son gone a gas, ney
# i'm alive, i'm alive, i'm alive, i'm alive, i'm alive, i'm alive, i'm alive, i'm alive, i'm alive, i'm alive, i'm alive, i'm alive, i'm alive, i'm alive, i'm alive, i'm alive, i'm alive, i'm alive, i'm alive, i'm alive, i'm alive, i'm alive, i'm alive, i'm alive, i'm alive, i'm alive, i'm alive, i'm alive, i'm alive, i'm alive, i'm alive, i'm alive, i'm alive, yeah, oh yeah
#
# ----- diversity: 1.0
# ----- Generating with seed: " the air is still,
# all of a sudden i fe"
#  the air is still,
# all of a sudden i feel usk
#
# "abbotor thee girl i saw her an and i don't read your namold to the cat
# their himing when i was a mentelsee you're rock'r
#
# mak, my brain
#
# gonna keep that'' done
# batt's a says they rell you seeld that's a seew oh-oh-oh
#
# i don't wanna wan
# it the bightthies
#
# "i'm not cars
# it's the waind something
#
# i headbandveright they walk
#
# he when i saw her and we creatil how
# don't bust my croso h
#
# ----- diversity: 1.2
# ----- Generating with seed: " the air is still,
# all of a sudden i fe"
#  the air is still,
# all of a sudden i feel you want me
# he's go na, i donted do dayfrieven'
# rock n'trout my get
# but no hought for peesule
# jaukne a playne any out of there what
# i can't contuon
# you hard how you're dryme fovile
# c-oopes my frob me
# chop suey
# chop steegh
#
# you know thiegs whene
# i'm no goo
# now when your bick
# is a's goin'
# i usad and i'm youle
#
#
# cove thing is a mirth, i des a place ajaat
# and i was feeling ony div
#
# --------------------------------------------------
# Iteration 18
# Epoch 1/1
# 46336/51361 [==========================>...] - ETA: 2s - loss: 0.6999
