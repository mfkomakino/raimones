# %%
from __future__ import print_function
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.callbacks import ModelCheckpoint
from keras.layers import Dropout
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys

# %% [markdown]
# Hello Anselmo!

# %%
#path = get_file('all_lyrics_no-umlaut_edited2.txt', origin='http://research.komakino.ch/all_lyrics_no-umlaut_edited2.txt ')

filename = 'all_lyrics_no-umlaut_edited2.txt'

text = open(filename).read().lower()

text = text.replace('\x99', '')
text = text.replace('\x80', '')
text = text.replace('\xe2', '')


text = text.replace('"', '')
text = text.replace('(', '')
text = text.replace(')', '')
text = text.replace('_', '')
text = text.replace(';', ',')
text = text.replace('&amp;', '&')



#all_lyrics_no-umlaut_edited2.txt
#path = get_file('nietzsche.txt', origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
#text = open(path).read().lower()
print('corpus length:', len(text))
chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
#step = 1
sentences = []
next_chars = []
# Out:
# corpus length: 149346
# total chars: 47

# %%
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))
print('Vectorization...')
X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
# Out:
# nb sequences: 49769
# Vectorization...

# %%
for (i, sentence) in enumerate(sentences):
    for (t, char) in enumerate(sentence):
        X[i, t, char_indices[char]] = 1
        y[i, char_indices[next_chars[i]]] = 1

# %%
# build the model: a single LSTM
print('Build model...')

model = Sequential()
model.add(LSTM(128, return_sequences=True, input_shape=(maxlen, len(chars))))
model.add(Dropout(0.2))
model.add(LSTM(128, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(len(chars), activation='softmax'))


optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# Build model...

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
filename = "aws_128-128_02_length40_step3_batch128_weights-improvement-00-0.7539.hdf5"
model.load_weights(filename)

# %%
filepath="aws_128-128_02_length40_step3_batch128_weights-improvement-{epoch:02d}-{loss:.4f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min', period=1)
callbacks_list = [checkpoint]

# Word_weights-improvement-00-0.5946.hdf5


# train the model, output generated text after each iteration
for iteration in range(1, 30):
    print()
    print('-' * 50)
    print('Iteration', iteration)
    history = model.fit(X, y,
              batch_size=128,
              epochs=1, 
              callbacks=callbacks_list)

    

    start_index = random.randint(0, len(text) - maxlen - 1)
    if (iteration%10==0):
        for diversity in [0.1, 0.2, 0.5, 1.0]:
            print()
            print('----- diversity:', diversity)

            generated = ''
            sentence = text[start_index: start_index + maxlen]
            generated += sentence
            print('----- Generating with seed: "' + sentence + '"')
            sys.stdout.write(generated)

            for i in range(200):
                x = np.zeros((1, maxlen, len(chars)))
                for t, char in enumerate(sentence):
                    x[0, t, char_indices[char]] = 1.

                preds = model.predict(x, verbose=0)[0]
                next_index = sample(preds, diversity)
                next_char = indices_char[next_index]

                generated += next_char
                sentence = sentence[1:] + next_char

                sys.stdout.write(next_char)
                sys.stdout.flush()
            print()
# Out:
# --------------------------------------------------
# Iteration 1
# Epoch 1/1
# Epoch 00000: loss improved from inf to 0.71308, saving model to aws_128-128_02_length40_step3_batch128_weights-improvement-00-0.7131.hdf5
# 49769/49769 [==============================] - 66s - loss: 0.7131
#
# --------------------------------------------------
# Iteration 2
# Epoch 1/1
# Epoch 00000: loss did not improve
# 49769/49769 [==============================] - 66s - loss: 0.7272
#
# --------------------------------------------------
# Iteration 3
# Epoch 1/1
# Epoch 00000: loss did not improve
# 49769/49769 [==============================] - 66s - loss: 0.7432
#
# --------------------------------------------------
# Iteration 4
# Epoch 1/1
# Epoch 00000: loss did not improve
# 49769/49769 [==============================] - 66s - loss: 0.8320
#
# --------------------------------------------------
# Iteration 5
# Epoch 1/1
# Epoch 00000: loss did not improve
# 49769/49769 [==============================] - 66s - loss: 0.9107
#
# --------------------------------------------------
# Iteration 6
# Epoch 1/1
# Epoch 00000: loss did not improve
# 49769/49769 [==============================] - 65s - loss: 1.0136
#
# --------------------------------------------------
# Iteration 7
# Epoch 1/1
# Epoch 00000: loss did not improve
# 49769/49769 [==============================] - 49s - loss: 0.9383
#
# --------------------------------------------------
# Iteration 8
# Epoch 1/1
# Epoch 00000: loss did not improve
# 49769/49769 [==============================] - 41s - loss: 0.9536
#
# --------------------------------------------------
# Iteration 9
# Epoch 1/1
# Epoch 00000: loss did not improve
# 49769/49769 [==============================] - 41s - loss: 0.9292
#
# --------------------------------------------------
# Iteration 10
# Epoch 1/1
# Epoch 00000: loss did not improve
# 49769/49769 [==============================] - 41s - loss: 1.1000
#
# ----- diversity: 0.1
# ----- Generating with seed: "o blame, for people acting this way
# tel"
# o blame, for people acting this way
# tell me what they took a
# /home/ubuntu/.local/lib/python2.7/site-packages/ipykernel/__main__.py:4: RuntimeWarning: divide by zero encountered in log
# ll the lid and then your body
# i don't wanna be alright
# i don't wanna be alright
# i don't wanna be alright
# i don't wanna be alright
# i don't wanna be alright
# i don't wanna be a
#
# ----- diversity: 0.2
# ----- Generating with seed: "o blame, for people acting this way
# tel"
# o blame, for people acting this way
# tell me what they want to the way the hey well what they do you wanna live
# you can't seem themers of spreating hope and see surfin' safari with me
# come on and safari with me
# and i want you anythe wat
#
# ----- diversity: 0.5
# ----- Generating with seed: "o blame, for people acting this way
# tel"
# o blame, for people acting this way
# tell me shis love you chiles and start of the way
# i want to be from coaf
# i don't want to be the dangers, it's the clos life
# you can't control fread
# now you can't seem to me so baby
# you see your on t
#
# ----- diversity: 1.0
# ----- Generating with seed: "o blame, for people acting this way
# tel"
# o blame, for people acting this way
# tell me woriang the time stop lifes a plean
# but when it't onees
# i can't nothing to loves probabe
# and with with ut thee do
#
# now the start ever and went fating wrien
# they do you wanna me ain't do
# to
#
# --------------------------------------------------
# Iteration 11
# Epoch 1/1
# Epoch 00000: loss did not improve
# 49769/49769 [==============================] - 41s - loss: 1.1541
#
# --------------------------------------------------
# Iteration 12
# Epoch 1/1
# Epoch 00000: loss did not improve
# 49769/49769 [==============================] - 41s - loss: 1.2269
#
# --------------------------------------------------
# Iteration 13
# Epoch 1/1
# Epoch 00000: loss did not improve
# 49769/49769 [==============================] - 41s - loss: 1.2957
#
# --------------------------------------------------
# Iteration 14
# Epoch 1/1
# Epoch 00000: loss did not improve
# 49769/49769 [==============================] - 41s - loss: 1.7711
#
# --------------------------------------------------
# Iteration 15
# Epoch 1/1
# Epoch 00000: loss did not improve
# 49769/49769 [==============================] - 41s - loss: 2.8654
#
# --------------------------------------------------
# Iteration 16
# Epoch 1/1
# Epoch 00000: loss did not improve
# 49769/49769 [==============================] - 41s - loss: 5.1228
#
# --------------------------------------------------
# Iteration 17
# Epoch 1/1
# Epoch 00000: loss did not improve
# 49769/49769 [==============================] - 41s - loss: 7.6648
#
# --------------------------------------------------
# Iteration 18
# Epoch 1/1
# Epoch 00000: loss did not improve
# 49769/49769 [==============================] - 41s - loss: 11.8658
#
# --------------------------------------------------
# Iteration 19
# Epoch 1/1
# Epoch 00000: loss did not improve
# 49769/49769 [==============================] - 41s - loss: 11.5087
#
# --------------------------------------------------
# Iteration 20
# Epoch 1/1
# Epoch 00000: loss did not improve
# 49769/49769 [==============================] - 41s - loss: 12.6694
#
# ----- diversity: 0.1
# ----- Generating with seed: "you remember rock'n'roll radio?
#
# do you"
# you remember rock'n'roll radio?
#
# do you   a o k 3 t
#   ha   a o t   eo      e  o      u       e  a    o    o u         i        e  ahe    a   :o w   a    o r  o            n t         &          o      e  o             o     o          r
#
# ----- diversity: 0.2
# ----- Generating with seed: "you remember rock'n'roll radio?
#
# do you"
# you remember rock'n'roll radio?
#
# do you   a o k : to      h  3 ho          o  o yoo n   2     oo  o o      n  e  h    9  o  o     e  on     me   a    o    d   o   d      t      s    o   o o        o        3     o     ro t       o      en
#
# ----- diversity: 0.5
# ----- Generating with seed: "you remember rock'n'roll radio?
#
# do you"
# you remember rock'n'roll radio?
#
# do you   a o k 6 to m   ro     o  o9o   o t   o    e   te     o              :      r      o n  m o6  o e  o   t o   o          9 to      e
# &     h t  o   h     n    o   o3   a   o    o  in
#
# ----- diversity: 1.0
# ----- Generating with seed: "you remember rock'n'roll radio?
#
# do you"
# you remember rock'n'roll radio?
#
#  o you   i o   o e     o a t           h            o o     o      h   n  a            at o n     f e  o    o      n  uo a o  i    1 at t    a       n a   oe  e    o
# o      t n   o  n  e  e o
#
# --------------------------------------------------
# Iteration 21
# Epoch 1/1
# Epoch 00000: loss did not improve
# 49769/49769 [==============================] - 41s - loss: 13.1373
#
# --------------------------------------------------
# Iteration 22
# Epoch 1/1
# Epoch 00000: loss did not improve
# 49769/49769 [==============================] - 41s - loss: 13.2515
#
# --------------------------------------------------
# Iteration 23
# Epoch 1/1
# Epoch 00000: loss did not improve
# 49769/49769 [==============================] - 41s - loss: 13.2507
#
# --------------------------------------------------
# Iteration 24
# Epoch 1/1
#  7680/49769 [===>..........................] - ETA: 35s - loss: 13.3179
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-0d6ec88931df> in <module>()
#      14               batch_size=128,
#      15               epochs=1,
# ---> 16               callbacks=callbacks_list)
#      17
#      18
#
# /home/ubuntu/.local/lib/python2.7/site-packages/keras/models.pyc in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#     854                               class_weight=class_weight,
#     855                               sample_weight=sample_weight,
# --> 856                               initial_epoch=initial_epoch)
#     857
#     858     def evaluate(self, x, y, batch_size=32, verbose=1,
#
# /home/ubuntu/.local/lib/python2.7/site-packages/keras/engine/training.pyc in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#    1496                               val_f=val_f, val_ins=val_ins, shuffle=shuffle,
#    1497                               callback_metrics=callback_metrics,
# -> 1498                               initial_epoch=initial_epoch)
#    1499
#    1500     def evaluate(self, x, y, batch_size=32, verbose=1, sample_weight=None):
#
# /home/ubuntu/.local/lib/python2.7/site-packages/keras/engine/training.pyc in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch)
#    1150                 batch_logs['size'] = len(batch_ids)
#    1151                 callbacks.on_batch_begin(batch_index, batch_logs)
# -> 1152                 outs = f(ins_batch)
#    1153                 if not isinstance(outs, list):
#    1154                     outs = [outs]
#
# /home/ubuntu/.local/lib/python2.7/site-packages/keras/backend/tensorflow_backend.pyc in __call__(self, inputs)
#    2227         session = get_session()
#    2228         updated = session.run(self.outputs + [self.updates_op],
# -> 2229                               feed_dict=feed_dict)
#    2230         return updated[:len(self.outputs)]
#    2231
#
# /home/ubuntu/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/ubuntu/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /home/ubuntu/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/ubuntu/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /home/ubuntu/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
